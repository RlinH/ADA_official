# %%
import torch
print(torch.__version__)

print(torch.version.cuda)
print(torch.backends.cudnn.version())
# Out:
# 2.2.1+cu118
# 11.8
# 8700

# %%
# %run train_polyp.py
# Out:
# ./dataset/polyp\CVC-ClinicDB\train\images/
# total 488 samples for train
# ./dataset/polyp\Kvasir-SEG\test\images/
# total 100 samples for test
# ./dataset/polyp\CVC-ColonDB\test\images/
# total 38 samples for test
# Training Progress:  72%|████████████████████████████████████████▊                | 215/300 [2:52:22<1:10:51, 50.01s/it]

# %%
# %run train_fundus.py
# Out:
# ./dataset/Fundus\Domain3\train/ROIs\image
# Number of images in train/ROIs: 320
# ./dataset/Fundus\Domain2\test/ROIs\image
# Number of images in test/ROIs: 60
# ./dataset/Fundus\Domain4\test/ROIs\image
# Number of images in test/ROIs: 80
# Training Progress:   0%|          | 0/200 [00:00<?, ?it/s]
# ./dataset/Fundus\Domain1\test/ROIs\image
# Number of images in test/ROIs: 51
# ./dataset/Fundus\Domain2\test/ROIs\image
# Number of images in test/ROIs: 60
# ./dataset/Fundus\Domain3\test/ROIs\image
# Number of images in test/ROIs: 80
# ./dataset/Fundus\Domain4\test/ROIs\image
# Number of images in test/ROIs: 80
# -----Dataset: Domain3--------
# CUP_dice: 0.8598
# DISC_dice: 0.9556
# MEAN_dice: 0.9077
# CUP_iou: 0.7676
# DISC_iou: 0.9155
# MEAN_iou: 0.8415
# CUP_dice: 0.7946
# DISC_dice: 0.8691
# MEAN_dice: 0.8318
# CUP_iou: 0.6776
# DISC_iou: 0.7721
# MEAN_iou: 0.7249
# CUP_dice: 0.8745
# DISC_dice: 0.9572
# MEAN_dice: 0.9158
# CUP_iou: 0.7817
# DISC_iou: 0.9184
# MEAN_iou: 0.8501
# ...

# %%
# %run train_prostatev2.py
# Out:
# total 162 samples for full
# total 387 samples for full
# total 354 samples for full
# Training Progress:  76%|██████████████████████████████████████████████▎              | 152/200 [35:12<13:16, 16.59s/it]
# Average Validation Loss: 0.0405
# Average Dice Score: 0.8078
# Training Progress:  76%|██████████████████████████████████████████████▋              | 153/200 [35:28<12:56, 16.51s/it]
# Average Validation Loss: 0.0339
# Average Dice Score: 0.8338
# Training Progress:  77%|██████████████████████████████████████████████▉              | 154/200 [35:40<11:41, 15.25s/it]
# Average Validation Loss: 0.0376
# Average Dice Score: 0.8118
# Training Progress:  78%|███████████████████████████████████████████████▎             | 155/200 [35:54<11:08, 14.85s/it]
# Average Validation Loss: 0.0368
# Average Dice Score: 0.8203
# Training Progress:  78%|███████████████████████████████████████████████▌             | 156/200 [36:08<10:36, 14.46s/it]
# Average Validation Loss: 0.0384
# ...
